# %%
import requests

# %%
req = requests.get("https://www.ccny.cuny.edu/registrar/fall")

# %%
req.status_code
# Out:
# 200

# %%
req.text[:1000]
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n  <head>\n    <meta charset="utf-8" /><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-83581f4fb59b51cbeb7",applicationID:"254978615"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function 
# ...

# %%
print(req.text[:1000])
# Out:
# <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#   <head>
# ...

# %%
len(req.text)
# Out:
# 137292

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(req.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# <head>
# ...

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.text
# Out:
# 'Fall 2021 Academic Calendar | The City College of New York'

# %%
soup.p
# Out:
# <p> </p>

# %%
all_p = soup.find_all('p')

# %%
len(all_p)
# Out:
# 105

# %%
all_tables = soup.find_all('table')

# %%
len(all_tables)
# Out:
# 1

# %%
ccnyCalenderTable = [table for table in all_tables]

# %%
len(ccnyCalenderTable)
# Out:
# 1

# %%
from IPython.display import HTML

# %%
HTML(ccnyCalenderTable[0].prettify())
# Out:
# <table align="center" border="3" cellpadding="1" cellspacing="1" style="width:1272px">
#  <thead>
#   <tr>
#    <th class="text-align-left" scope="col" style="width: 305px;">
#     DATES
#    </th>
#    <th class="text-align-left" scope="col" style="width: 327px;">
#     DAYS
#    </th>
#    <th scope="col" style="width: 617px;">
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <td style="width:305px">
#     <p>
#      <strong>
#       August 01
#      </strong>
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      <strong>
#       Sunday
#      </strong>
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
#      <strong>
#       Application for degree for January and February 2022 begins
#      </strong>
#     </p>
#    </td>
#   </tr>
#   <tr>
#    <td style="width:305px">
#     <p>
#      August 18
#     </p>
#    </td>
#    <td style="width:327px">
#     <p>
#      Wednesday
#     </p>
#    </td>
#    <td style="width:617px">
#     <p>
# ...

# %%
rows = [row for row in ccnyCalenderTable[0].find_all('tr')]

# %%
row = [0]

# %%
col_heads = [col.get_text() for col in rows[0].find_all('th')]
col_heads
# Out:
# ['DATES', 'DAYS', '\xa0']

# %%
data_rows = rows[1:]
HTML(data_rows[0].prettify())
# Out:
# <tr>
#  <td style="width:305px">
#   <p>
#    <strong>
#     August 01
#    </strong>
#   </p>
#  </td>
#  <td style="width:327px">
#   <p>
#    <strong>
#     Sunday
#    </strong>
#   </p>
#  </td>
#  <td style="width:617px">
#   <p>
#    <strong>
#     Application for degree for January and February 2022 begins
#    </strong>
#   </p>
#  </td>
# </tr>

# %%
value_series = [row.find_all('td') for row in data_rows]

# %%
value_series[:10]
# Out:
# [[<td style="width:305px">
#   <p><strong>August 01</strong></p>
#   </td>,
#   <td style="width:327px">
#   <p><strong>Sunday</strong></p>
#   </td>,
#   <td style="width:617px">
#   <p><strong>Application for degree for January and February 2022 begins</strong></p>
#   </td>],
#  [<td style="width:305px">
#   <p>August 18</p>
#   </td>,
#   <td style="width:327px">
#   <p>Wednesday</p>
#   </td>,
#   <td style="width:617px">
#   <p>Last day to apply for Study Abroad</p>
#   </td>],
#  [<td style="width:305px">
#   <p><strong>August 24</strong></p>
#   </td>,
#   <td style="width:327px">
#   <p><strong>Tuesday</strong></p>
#   </td>,
#   <td style="width:617px">
#   <p><strong>Last day of Registration;<br/>
#   			Last day to file ePermit for the Fall 2021;<br/>
#   			Last day to drop classes for 100% tuition refund;</strong></p>
#   </td>],
#  [<td style="width:305px">
#   <p>August 25</p>
#   </td>,
#   <td style="width:327px">
#   <p>Wednesday</p>
#   </td>,
# ...

# %%
value_rows = [[col.get_text().strip() for col in row.find_all('td')]  for row in data_rows] 
value_rows[:10]
# Out:
# [['August 01',
#   'Sunday',
#   'Application for degree for January and February 2022 begins'],
#  ['August 18', 'Wednesday', 'Last day to apply for Study Abroad'],
#  ['August 24',
#   'Tuesday',
#   'Last day of Registration;\n\t\t\tLast day to file ePermit for the Fall 2021;\n\t\t\tLast day to drop classes for 100% tuition refund;'],
#  ['August 25',
#   'Wednesday',
#   'Start of Fall Term;\n\t\t\tClasses begin;\n\t\t\tInitial Registration Appeals begin;'],
#  ['August 25 - 31',
#   'Wednesday - Tuesday',
#   'Change of program period; late fees apply'],
#  ['August 26', 'Thursday', 'Last day for Independent Study'],
#  ['August 28', 'Saturday', 'First day of Saturday Classes'],
#  ['August 31',
#   'Tuesday',
# ...

# %%
import numpy as np

# %%
numpy_value_rows = np.array(value_rows)

# %%
numpy_value_rows[:5].T
# Out:
# array([['August 01', 'August 18', 'August 24', 'August 25',
#         'August 25 - 31'],
#        ['Sunday', 'Wednesday', 'Tuesday', 'Wednesday',
#         'Wednesday - Tuesday'],
#        ['Application for degree for January and February 2022 begins',
#         'Last day to apply for Study Abroad',
#         'Last day of Registration;\n\t\t\tLast day to file ePermit for the Fall 2021;\n\t\t\tLast day to drop classes for 100% tuition refund;',
#         'Start of Fall Term;\n\t\t\tClasses begin;\n\t\t\tInitial Registration Appeals begin;',
#         'Change of program period; late fees apply']], dtype='<U294')

# %%
series_list = list(zip(*value_rows))
series_list[0]
# Out:
# ('August 01',
#  'August 18',
#  'August 24',
#  'August 25',
#  'August 25 - 31',
#  'August 26',
#  'August 28',
#  'August 31',
#  'September 01',
#  'September 03 - 08',
#  'September 06',
#  'September 09',
#  'September 14',
#  'September 15',
#  'September 15 - 16',
#  'September 23',
#  'September 24',
#  'October 01',
#  'October 08',
#  'October 11',
#  'November 01',
#  'November 02',
#  'November 04',
#  'November 06',
#  'November 23',
#  'November 25 - 28',
#  'December 11',
#  'December 13',
#  'December 14',
#  'December 15 - 21',
#  'December 21',
#  'December 24 - 25',
#  'December 27',
#  'December 28',
#  'December 31',
#  'January 1, 2022')

# %%
col_heads
# Out:
# ['DATES', 'DAYS', '\xa0']

# %%
import pandas as pd

# %%
df = pd.DataFrame(dict(zip(col_heads, series_list)))

# %%
df.head()
# Out:
#             DATES                 DAYS  \
# 0       August 01               Sunday
# 1       August 18            Wednesday
# 2       August 24              Tuesday
# 3       August 25            Wednesday
# 4  August 25 - 31  Wednesday - Tuesday
#
#
# 0  Application for degree for January and Februar...
# 1                 Last day to apply for Study Abroad
# 2  Last day of Registration;\n\t\t\tLast day to f...
# 3  Start of Fall Term;\n\t\t\tClasses begin;\n\t\...
# 4          Change of program period; late fees apply

# %%
df.tail()
# Out:
#                DATES               DAYS  \
# 31  December 24 - 25  Friday - Saturday
# 32       December 27             Monday
# 33       December 28            Tuesday
# 34       December 31             Friday
# 35   January 1, 2022           Saturday
#
#
# 31                                     College Closed
# 32                                     College Closed
# 33      Final Grade Submission Deadline for Fall 2021
# 34                                     College Closed
# 35  College Closed;\n\t\t\tFall 2021 Degree Confer...

# %%
byDays = df.groupby('DAYS')

# %%
size_table = byDays.size()

# %%
print(size_table)
# Out:
# DAYS
# Friday                  4
# Friday - Saturday       1
# Friday - Wednesday      1
# Monday                  5
# Saturday                4
# Sunday                  1
# Thursday                4
# Thursday - Sunday       1
# Tuesday                 8
# Wednesday               4
# Wednesday - Thursday    1
# Wednesday - Tuesday     2
# dtype: int64

# %%
size_table.sort_values(ascending=False)
# Out:
# DAYS
# Tuesday                 8
# Monday                  5
# Friday                  4
# Saturday                4
# Thursday                4
# Wednesday               4
# Wednesday - Tuesday     2
# Friday - Saturday       1
# Friday - Wednesday      1
# Sunday                  1
# Thursday - Sunday       1
# Wednesday - Thursday    1
# dtype: int64

# %%
HTML(str(ccnyCalenderTable[0]))
# Out:
# <table align="center" border="3" cellpadding="1" cellspacing="1" style="width:1272px">
# <thead>
# <tr>
# <th class="text-align-left" scope="col" style="width: 305px;">DATES</th>
# <th class="text-align-left" scope="col" style="width: 327px;">DAYS</th>
# <th scope="col" style="width: 617px;"> </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="width:305px">
# <p><strong>August 01</strong></p>
# </td>
# <td style="width:327px">
# <p><strong>Sunday</strong></p>
# </td>
# <td style="width:617px">
# <p><strong>Application for degree for January and February 2022 begins</strong></p>
# </td>
# </tr>
# <tr>
# <td style="width:305px">
# <p>August 18</p>
# </td>
# <td style="width:327px">
# <p>Wednesday</p>
# </td>
# <td style="width:617px">
# <p>Last day to apply for Study Abroad</p>
# </td>
# </tr>
# <tr>
# <td style="width:305px">
# <p><strong>August 24</strong></p>
# </td>
# <td style="width:327px">
# <p><strong>Tuesday</strong></p>
# </td>
# <td style="width:617px">
# ...

# %%
df2 = pd.read_html(str(ccnyCalenderTable[0]))[0]

# %%
df2
# Out:
#                 DATES       Day of the week  \
# 0           August 01                Sunday
# 1           August 18             Wednesday
# 2           August 24               Tuesday
# 3           August 25             Wednesday
# 4      August 25 - 31   Wednesday - Tuesday
# 5           August 26              Thursday
# 6           August 28              Saturday
# 7           August 31               Tuesday
# 8        September 01             Wednesday
# 9   September 03 - 08    Friday - Wednesday
# 10       September 06                Monday
# 11       September 09              Thursday
# 12       September 14               Tuesday
# 13       September 15             Wednesday
# 14  September 15 - 16  Wednesday - Thursday
# 15       September 23              Thursday
# 16       September 24                Friday
# 17         October 01                Friday
# 18         October 08                Friday
# 19         October 11                Monday
# ...

# %%
df2.head()
# Out:
#             DATES      Day of the week  \
# 0       August 01               Sunday
# 1       August 18            Wednesday
# 2       August 24              Tuesday
# 3       August 25            Wednesday
# 4  August 25 - 31  Wednesday - Tuesday
#
#                                           Unnamed: 2
# 0  Application for degree for January and Februar...
# 1                 Last day to apply for Study Abroad
# 2  Last day of Registration;  Last day to file eP...
# 3  Start of Fall Term;  Classes begin;  Initial R...
# 4          Change of program period; late fees apply

# %%
df2.rename( columns={'Unnamed: 2':'Text with Explanation'}, inplace=True )

# %%
df2
# Out:
#                 DATES       Day of the week  \
# 0           August 01                Sunday
# 1           August 18             Wednesday
# 2           August 24               Tuesday
# 3           August 25             Wednesday
# 4      August 25 - 31   Wednesday - Tuesday
# 5           August 26              Thursday
# 6           August 28              Saturday
# 7           August 31               Tuesday
# 8        September 01             Wednesday
# 9   September 03 - 08    Friday - Wednesday
# 10       September 06                Monday
# 11       September 09              Thursday
# 12       September 14               Tuesday
# 13       September 15             Wednesday
# 14  September 15 - 16  Wednesday - Thursday
# 15       September 23              Thursday
# 16       September 24                Friday
# 17         October 01                Friday
# 18         October 08                Friday
# 19         October 11                Monday
# ...

# %%
df2.rename(columns ={'DAYS':'Day of the week'}, inplace = True)

# %%
df2
# Out:
#                 DATES       Day of the week  \
# 0           August 01                Sunday
# 1           August 18             Wednesday
# 2           August 24               Tuesday
# 3           August 25             Wednesday
# 4      August 25 - 31   Wednesday - Tuesday
# 5           August 26              Thursday
# 6           August 28              Saturday
# 7           August 31               Tuesday
# 8        September 01             Wednesday
# 9   September 03 - 08    Friday - Wednesday
# 10       September 06                Monday
# 11       September 09              Thursday
# 12       September 14               Tuesday
# 13       September 15             Wednesday
# 14  September 15 - 16  Wednesday - Thursday
# 15       September 23              Thursday
# 16       September 24                Friday
# 17         October 01                Friday
# 18         October 08                Friday
# 19         October 11                Monday
# ...

# %%
import os.path

# %%
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
from googleapiclient.discovery import build

# %%
from google.oauth2.credentials import Credentials

# %%
scopes = ['https://www.googleapis.com/auth/calendar']

# %%
flow = InstalledAppFlow.from_client_secrets_file("client_secret2.json", scopes=scopes)

# %%
credentials = flow.run_console()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=135195072297-aeee635253c2av6tsitpvd62e9n5natg.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar&state=HT8YYG2Lwl7gMzcQy6TMcAzgeZnYmG&prompt=consent&access_type=offline
# Enter the authorization code: 4/1ARtbsJp9jBqifdUVKge9Gtzb4f0VOoqBnbCMu-gBBRqEreCKckUFhyFLUk8

# %%
import pickle

# %%
pickle.dump(credentials, open("token.pkl", "wb"))

# %%
credentials = pickle.load(open("token.pkl", "rb"))

# %%
service = build("calendar", "v3", credentials=credentials)

# %%
result = service.calendarList().list().execute()

# %%
result
# Out:
# {'kind': 'calendar#calendarList',
#  'etag': '"p32kf756jkqefk0g"',
#  'nextSyncToken': 'CKjzlNOmnPoCEhpzdW1haXlhdWRkaW4xOTk1QGdtYWlsLmNvbQ==',
#  'items': [{'kind': 'calendar#calendarListEntry',
#    'etag': '"1663433991639000"',
#    'id': 'sumaiyauddin1995@gmail.com',
#    'summary': 'sumaiyauddin1995@gmail.com',
#    'timeZone': 'America/New_York',
#    'colorId': '14',
#    'backgroundColor': '#9fe1e7',
#    'foregroundColor': '#000000',
#    'selected': True,
#    'accessRole': 'owner',
#    'defaultReminders': [{'method': 'popup', 'minutes': 30}],
#    'notificationSettings': {'notifications': [{'type': 'eventCreation',
#       'method': 'email'},
#      {'type': 'eventChange', 'method': 'email'},
#      {'type': 'eventCancellation', 'method': 'email'},
#      {'type': 'eventResponse', 'method': 'email'}]},
#    'primary': True,
#    'conferenceProperties': {'allowedConferenceSolutionTypes': ['hangoutsMeet']}},
#   {'kind': 'calendar#calendarListEntry',
# ...

# %%
result['items'][0]['id']
# Out:
# 'sumaiyauddin1995@gmail.com'

# %%
calendar_id = result['items'][0]['id']

# %%
result = service.events().list(calendarId=calendar_id).execute()

# %%
result
# Out:
# {'kind': 'calendar#events',
#  'etag': '"p33ketotvleefk0g"',
#  'summary': 'sumaiyauddin1995@gmail.com',
#  'updated': '2022-09-17T17:22:10.353Z',
#  'timeZone': 'America/New_York',
#  'accessRole': 'owner',
#  'defaultReminders': [{'method': 'popup', 'minutes': 30}],
#  'nextSyncToken': 'COju47-rnPoCEOju47-rnPoCGAUgnbmE4gE=',
#  'items': [{'kind': 'calendar#event',
#    'etag': '"3326870613552000"',
#    'id': '1ka7vutq22g6itga1mm7eh0k57',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWthN3Z1dHEyMmc2aXRnYTFtbTdlaDBrNTcgc3VtYWl5YXVkZGluMTk5NUBt',
#    'created': '2022-09-17T17:21:46.000Z',
#    'updated': '2022-09-17T17:21:46.776Z',
#    'summary': 'SAMPLE EVENT',
#    'creator': {'email': 'sumaiyauddin1995@gmail.com', 'self': True},
#    'organizer': {'email': 'sumaiyauddin1995@gmail.com', 'self': True},
#    'start': {'dateTime': '2022-09-17T14:00:00-04:00',
#     'timeZone': 'America/New_York'},
# ...

# %%
result['items'][0]['summary']
# Out:
# 'SAMPLE EVENT'

# %%
event = {
  'summary': 'Inserting a new event',
  'location': '800 Howard St., San Francisco, CA 94103',
  'description': 'A chance to hear more about Google\'s developer products.',
  'start': {
    'dateTime': '2022-09-17T15:00:00-07:00',
    'timeZone': 'America/Los_Angeles',
  },
  'end': {
    'dateTime': '2022-09-17T16:00:00-07:00',
    'timeZone': 'America/Los_Angeles',
  },
  'recurrence': [
    'RRULE:FREQ=DAILY;COUNT=2'
  ],
  'attendees': [
    {'email': 'lpage@example.com'},
    {'email': 'sbrin@example.com'},
  ],
  'reminders': {
    'useDefault': False,
    'overrides': [
      {'method': 'email', 'minutes': 24 * 60},
      {'method': 'popup', 'minutes': 10},
    ],
  },
}

# %%
service.events().insert(calendarId=calendar_id, body=event).execute()
# Out:
# {'kind': 'calendar#event',
#  'etag': '"3326872177618000"',
#  'id': 'isbm6ct2e5n9n7i56hrdufu3bk',
#  'status': 'confirmed',
#  'htmlLink': 'https://www.google.com/calendar/event?eid=aXNibTZjdDJlNW45bjdpNTZocmR1ZnUzYmtfMjAyMjA5MTdUMjIwMDAwWiBzdW1haXlhdWRkaW4xOTk1QG0',
#  'created': '2022-09-17T17:34:47.000Z',
#  'updated': '2022-09-17T17:34:49.057Z',
#  'summary': 'Inserting a new event',
#  'description': "A chance to hear more about Google's developer products.",
#  'location': '800 Howard St., San Francisco, CA 94103',
#  'creator': {'email': 'sumaiyauddin1995@gmail.com', 'self': True},
#  'organizer': {'email': 'sumaiyauddin1995@gmail.com', 'self': True},
#  'start': {'dateTime': '2022-09-17T18:00:00-04:00',
#   'timeZone': 'America/Los_Angeles'},
#  'end': {'dateTime': '2022-09-17T19:00:00-04:00',
#   'timeZone': 'America/Los_Angeles'},
#  'recurrence': ['RRULE:FREQ=DAILY;COUNT=2'],
#  'iCalUID': 'isbm6ct2e5n9n7i56hrdufu3bk@google.com',
#  'sequence': 0,
# ...
